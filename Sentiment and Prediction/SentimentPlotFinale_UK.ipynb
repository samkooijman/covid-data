# %%
import pandas as pd
import matplotlib.pyplot as plt
from sqlalchemy import create_engine, inspect, Table

# %%
import pandas as pd
df = pd.read_csv("tweetid_userid_keyword_sentiments_emotions_United Kingdom.csv", nrows = 99999)

# Deleting redundant columns 
df = df.iloc[: , 1:]

# Splitting timestamp and replacing it in df
df['tweet_timestamp'] = df['tweet_timestamp'].str.split(' ').str[0]
df
# Out:
#                    user_id tweet_timestamp keyword  valence_intensity  \
# 0      1060575080856608768      2020-01-27   wuhan              0.512
# 1               2318820202      2020-01-27   wuhan              0.397
# 2                295863148      2020-01-27   wuhan              0.408
# 3                157610181      2020-01-27   wuhan              0.370
# 4       885628806362484737      2020-01-27   wuhan              0.494
# ...                    ...             ...     ...                ...
# 99994            728854819      2020-03-02  corona              0.326
# 99995           1235184998      2020-03-02  corona              0.420
# 99996            295222532      2020-03-02  corona              0.503
# 99997           1005038540      2020-03-02    nCoV              0.464
# 99998  1231508155227680768      2020-03-02  corona              0.392
#
#        fear_intensity  anger_intensity  happiness_intensity  \
# 0               0.553            0.386                0.390
# 1               0.542            0.526                0.285
# 2               0.539            0.514                0.238
# 3               0.678            0.464                0.247
# 4               0.457            0.418                0.335
# ...               ...              ...                  ...
# 99994           0.587            0.600                0.191
# 99995           0.431            0.548                0.312
# 99996           0.352            0.357                0.325
# 99997           0.431            0.484                0.224
# 99998           0.426            0.408                0.233
#
#        sadness_intensity         sentiment              emotion
# 0                  0.394  neutral or mixed  no specific emotion
# 1                  0.494          negative                 fear
# 2                  0.478          negative                 fear
# 3                  0.558          negative                 fear
# 4                  0.411  neutral or mixed  no specific emotion
# ...                  ...               ...                  ...
# 99994              0.501          negative                anger
# 99995              0.412          negative                anger
# 99996              0.350  neutral or mixed  no specific emotion
# 99997              0.425          negative                anger
# 99998              0.378          negative                 fear
#
# [99999 rows x 10 columns]

# %%
# Imports
from sqlalchemy import create_engine, inspect, Table
# Open a connection to the postgresql database
db_conn = create_engine("postgresql://student:infomdss@db_assignments:5432/covid")

# %%
db_conn.execute("DROP TABLE IF EXISTS df CASCADE;")

# %%
df.to_sql("df", db_conn)

# %%
displa

# %%
fear = '''
SELECT count(df.emotion) as fear, tweet_timestamp
FROM df
where emotion = 'fear'
group by tweet_timestamp
order by tweet_timestamp


'''

#############################
    
table_fear = pd.read_sql(fear, db_conn)
print(table_fear)
fear = pd.DataFrame(table_fear)
fear
# Out:
#     fear tweet_timestamp
# 0     45      2020-01-27
# 1   1343      2020-01-28
# 2   1682      2020-01-29
# 3   1999      2020-01-30
# 4   2363      2020-01-31
# 5   1049      2020-02-01
# 6   1131      2020-02-02
# 7    991      2020-02-03
# 8    887      2020-02-04
# 9    519      2020-02-05
# 10   924      2020-02-06
# 11  1025      2020-02-07
# 12   857      2020-02-08
# 13   679      2020-02-09
# 14  1104      2020-02-10
SELECT count(df.emotion) as sadness, tweet_timestamp
FROM df
where emotion = 'sadness'
group by tweet_timestamp
order by tweet_timestamp


'''

#############################
table_sadness = pd.read_sql(sadness, db_conn)
print(table_sadness)

sadness = pd.DataFrame(table_sadness)
sadness
# Out:
#     sadness tweet_timestamp
# 0         2      2020-01-27
# 1        60      2020-01-28
# 2        91      2020-01-29
# 3       107      2020-01-30
# 4       140      2020-01-31
# 5        73      2020-02-01
# 6        42      2020-02-02
# 7        52      2020-02-03
# 8        49      2020-02-04
# 9        25      2020-02-05
# 10       42      2020-02-06
# 11       68      2020-02-07
# 12       63      2020-02-08
# 13       46      2020-02-09
# 14       56      2020-02-10
# 15       76      2020-02-11
# 16       55      2020-02-12
# 17       62      2020-02-13
# 18       50      2020-02-14
# 19       32      2020-02-15
# 20       28      2020-02-16
# 21       45      2020-02-17
# 22       46      2020-02-18
# 23       51      2020-02-19
# 24       40      2020-02-20
# 25       48      2020-02-21
# 26       33      2020-02-22
# 27       51      2020-02-23
# 28       67      2020-02-24
# 29      103      2020-02-25
# 30      166      2020-02-26
# 31      189      2020-02-27
# 32      304      2020-02-28
# 33      151      2020-02-29
# 34      149      2020-03-01
# 35       98      2020-03-02
#     sadness tweet_timestamp
# 0         2      2020-01-27
# 1        60      2020-01-28
# 2        91      2020-01-29
# 3       107      2020-01-30
# 4       140      2020-01-31
# 5        73      2020-02-01
# 6        42      2020-02-02
# 7        52      2020-02-03
# 8        49      2020-02-04
# 9        25      2020-02-05
# 10       42      2020-02-06
# 11       68      2020-02-07
# 12       63      2020-02-08
# 13       46      2020-02-09
# 14       56      2020-02-10
# 15       76      2020-02-11
# 16       55      2020-02-12
# 17       62      2020-02-13
# 18       50      2020-02-14
# 19       32      2020-02-15
# 20       28      2020-02-16
# 21       45      2020-02-17
# 22       46      2020-02-18
# 23       51      2020-02-19
# 24       40      2020-02-20
# 25       48      2020-02-21
# 26       33      2020-02-22
# 27       51      2020-02-23
# 28       67      2020-02-24
# 29      103      2020-02-25
# 30      166      2020-02-26
# 31      189      2020-02-27
# 32      304      2020-02-28
# 33      151      2020-02-29
# 34      149      2020-03-01
# 35       98      2020-03-02

# %%
no_specific_emotion = '''
SELECT count(df.emotion) as no_specific_emotion, tweet_timestamp
FROM df
where emotion = 'no specific emotion'
group by tweet_timestamp
order by tweet_timestamp


'''

#############################
 
table_no_specific_emotion = pd.read_sql(no_specific_emotion, db_conn)
print(table_no_specific_emotion)

no_specific_emotion = pd.DataFrame(table_no_specific_emotion)
# Out:
#     no_specific_emotion tweet_timestamp
# 0                    18      2020-01-27
# 1                   405      2020-01-28
# 2                   492      2020-01-29
# 3                   603      2020-01-30
# 4                   798      2020-01-31
# 5                   356      2020-02-01
# 6                   339      2020-02-02
# 7                   330      2020-02-03
# 8                   285      2020-02-04
# 9                   215      2020-02-05
# 10                  266      2020-02-06
# 11                  278      2020-02-07
# 12                  243      2020-02-08
# 13                  262      2020-02-09
# 14                  284      2020-02-10
# 15                  407      2020-02-11
# 16                  413      2020-02-12
# 17                  406      2020-02-13
# 18                  353      2020-02-14
# 19                  226      2020-02-15
# 20                  193      2020-02-16
# 21                  240      2020-02-17
# 22                  301      2020-02-18
# 23                  223      2020-02-19
# 24                  268      2020-02-20
# 25                  203      2020-02-21
# 26                  189      2020-02-22
# 27                  307      2020-02-23
# 28                  407      2020-02-24
# 29                  546      2020-02-25
# 30                  807      2020-02-26
# 31                  925      2020-02-27
# 32                 1295      2020-02-28
# 33                  776      2020-02-29
# 34                  829      2020-03-01
# 35                  488      2020-03-02

# %%
anger = '''
SELECT count(df.emotion) as anger, tweet_timestamp
FROM df
where emotion = 'anger'
group by tweet_timestamp
order by tweet_timestamp


'''

#############################

table_anger = pd.read_sql(anger, db_conn)
print(table_anger)

anger = pd.DataFrame(table_anger)
# Out:
#     anger tweet_timestamp
# 0       8      2020-01-27
# 1     492      2020-01-28
# 2     536      2020-01-29
# 3     726      2020-01-30
# 4    1124      2020-01-31
# 5     480      2020-02-01
# 6     422      2020-02-02
# 7     339      2020-02-03
# 8     253      2020-02-04
# 9      89      2020-02-05
# 10    268      2020-02-06
# 11    332      2020-02-07
# 12    336      2020-02-08
# 13    230      2020-02-09
# 14    437      2020-02-10
# 15    499      2020-02-11
# 16    492      2020-02-12
# 17    553      2020-02-13
# 18    419      2020-02-14
# 19    313      2020-02-15
# 20    274      2020-02-16
# 21    284      2020-02-17
# 22    363      2020-02-18
# 23    237      2020-02-19
# 24    248      2020-02-20
# 25    225      2020-02-21
# 26    217      2020-02-22
# 27    375      2020-02-23
# 28    499      2020-02-24
# 29    786      2020-02-25
# 30   1023      2020-02-26
# 31   1299      2020-02-27
# 32   2307      2020-02-28
# 33   1510      2020-02-29
# 34   1282      2020-03-01
# 35    670      2020-03-02

# %%
df1 = (pd.merge(anger, fear, on='tweet_timestamp'))
df2 = (pd.merge(df1, happiness, on='tweet_timestamp'))
df3 = (pd.merge(df2, no_specific_emotion, on='tweet_timestamp'))
df4 = (pd.merge(df3, sadness, on='tweet_timestamp'))

# to date type
df4['tweet_timestamp'] = pd.to_datetime(df4.tweet_timestamp)
#df4['tweet_timestamp'].dt.strftime("%Y%m%d").astype(int)
#df4['tweet_timestamp'].str.replace("-","").astype(float)
df4.to_csv('UKsentimentframe.csv')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
from matplotlib.pyplot import figure

figure(figsize=(12, 20
               ), dpi=80)

x1 = df4.tweet_timestamp 
y1 = df4.fear
y2 = df4.anger
y3 = df4.happiness
y4 = df4.sadness
plt.plot(x1, y1)
plt.plot(x1, y2)
plt.plot(x1, y3)
plt.plot(x1, y4)

plt.legend(["fear ", "anger", "happiness", "sadness"])
